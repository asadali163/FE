# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../../data/France/processed_data/sell_in.csv")

# %%
df.head()
# Out:
#    sales_date_raw  pos_code        outlet_sf_id  sku_code           sku_sf_id  \
# 0        20260105    300003  0011t000011b5fiAAA     86195  a0U3W000002A7QeUAK
# 1        20260105    300003  0011t000011b5fiAAA     86196  a0U3W000002A7QtUAK
# 2        20260105    300003  0011t000011b5fiAAA     87571  a0UJz000005H9AVMA0
# 3        20260105    300003  0011t000011b5fiAAA     87866  a0UJz000009Ce1KMAS
# 4        20260105    300003  0011t000011b5fiAAA     87884  a0UJz000009CevlMAC
#
#           sku_record  delivery_date_raw  base_unit  outer_unit        date  \
# 0          Trade SKU           20260106          5           1  2026-01-05
# 1          Trade SKU           20260106         15           3  2026-01-05
# 2          Trade SKU           20260106         10           2  2026-01-05
# 3  Manufacturing SKU           20260106          5           1  2026-01-05
# 4  Manufacturing SKU           20260106          5           1  2026-01-05
#
# ...

# %%
df["sku_sf_id"].value_counts()
# Out:
# sku_sf_id
# 0                     14703
# a0U1t000002PXlqEAG     4095
# a0U3W000002BYaXUAW     4013
# a0U1t000002PXloEAG     3853
# a0U1t000002PXnYEAW     3775
#                       ...
# a0U3W000004XPHyUAO        1
# a0U3W000000eRFeUAM        1
# a0U3W000002AEgPUAW        1
# a0U3W000002AEk1UAG        1
# a0U1t000002Pww2EAC        1
# Name: count, Length: 202, dtype: int64

# %%
df.shape
# Out:
# (122307, 16)
