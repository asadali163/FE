# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df_sell_in = pd.read_csv("/home/asad/Desktop/footfall_explorer/data/France/processed_data/sell_in_merged.csv")

df_sell_out = pd.read_csv("/home/asad/Desktop/footfall_explorer/data/France/processed_data/sell_out_merged.csv")
# Out:
# /tmp/ipykernel_23205/2697493990.py:1: DtypeWarning: Columns (3,4,5,6,9,10,11,12,25,26,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sell_in = pd.read_csv("/home/asad/Desktop/footfall_explorer/data/France/processed_data/sell_in_merged.csv")

# %%
df_sell_in.shape, df_sell_out.shape
# Out:
# ((122307, 34), (664143, 13))

# %%
df_sell_in.head()
# Out:
#          date        outlet_sf_id  sku_code          sku_code.1 sku_sf_id  \
# 0  2026-01-05  0011t000011b5fiAAA     86195  a0U3W000002A7QeUAK       NaN
# 1  2026-01-05  0011t000011bCJaAAM     85548  a0U3W000002BYaXUAW       NaN
# 2  2026-01-05  0011t000011bCJaAAM     86175  a0U3W000002BYagUAG       NaN
# 3  2026-01-05  0011t000011bCJaAAM     99999                 NaN       NaN
# 4  2026-01-05  0011t000011bCJaAAM     99999                 NaN       NaN
#
#   sku_sf_id.1 record_type  sales_quantity  sales_amount sku_sf_id.2  ...  \
# 0         NaN         NaN               5             1         NaN  ...
# 1         NaN         NaN             800             4         NaN  ...
# 2         NaN         NaN             200             1         NaN  ...
# 3         NaN         NaN               0             0         NaN  ...
# 4         NaN         NaN            6440            32         NaN  ...
#
#   sku_code.2          sku_code.3                                   sku_name  \
# ...

# %%
df_sell_out.head()
# Out:
#          date  customer_code        customer_name  latitude  longitude  \
# 0  2026-02-01       576579.0       576579 - TABAC  48.86806    2.35239
# 1  2026-02-01       576579.0       576579 - TABAC  48.86806    2.35239
# 2  2026-02-01       576579.0       576579 - TABAC  48.86806    2.35239
# 3  2026-02-01       307057.0  307057 - CAPRI (LE)  48.89021    2.32111
# 4  2026-02-01       307057.0  307057 - CAPRI (LE)  48.89021    2.32111
#
#          territory_id                         territory_name channel_name  \
# 0  a0D1t000005iLAGEA2  France_FRDiv_Reg1_AREA_A_SECTEUR_A_01  Independent
# 1  a0D1t000005iLAGEA2  France_FRDiv_Reg1_AREA_A_SECTEUR_A_01  Independent
# 2  a0D1t000005iLAGEA2  France_FRDiv_Reg1_AREA_A_SECTEUR_A_01  Independent
# 3  a0D1t000005iLAnEAM  France_FRDiv_Reg1_AREA_A_SECTEUR_A_06         COCO
# 4  a0D1t000005iLAnEAM  France_FRDiv_Reg1_AREA_A_SECTEUR_A_06         COCO
#
#    brand_name        category            sku_code  Volume in Unit  \
# ...

# %%
si = df_sell_in.copy()
so = df_sell_out.copy()
