# %%
import pandas as pd
import os

# %%
# check current directory. 
print(os.getcwd())
# Out:
# /home/asad/Desktop/footfall_explorer/src/footfall_explorer/notebooks

# %%
df = pd.read_csv("../../../data/raw/events_43.3016_5.368_20260401_114511.csv")

# %%
df.head()
# Out:
#        source        id                                               name  \
# 0  OpenAgenda  13352502  Accueil de groupe hors programmation grand public
# 1  OpenAgenda  55548252  RENDEZ-VOUS AVEC POSITIV (Accompagnement à la ...
# 2  OpenAgenda  39651718           FORMATION TFP Cuisine AFC GROUPE Aubagne
# 3  OpenAgenda    367073  RENDEZ-VOUS AVEC POSITIV (Accompagnement à la ...
# 4  OpenAgenda  82855055  RENDEZ-VOUS AVEC POSITIV (Accompagnement à la ...
#
#                                          description        date   time  \
# 0                 Spectacle conte  Parcours provence  2026-04-10  09:30
# 1  Rencontre individuelle avec Cynthia Ouzahrir C...  2026-04-01  09:00
# 2  AFC GROUPE vous propose de découvrir la format...  2026-04-01  09:30
# 3  Rencontre individuelle avec Cynthia Ouzahrir C...  2026-04-01  09:30
# 4  Rencontre individuelle avec Cynthia Ouzahrir C...  2026-04-01  10:00
#
#   end_time                          venue       city            address  ...  \
# ...
